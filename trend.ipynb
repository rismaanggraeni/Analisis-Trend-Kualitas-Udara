# %%
import numpy as np
import pandas as pd
import pymannkendall as mk
import matplotlib.pyplot as plt
import statsmodels.api as sm
# %matplotlib inline

# %%
# read all datasets
df = pd.read_csv("NO2.csv",parse_dates=['waktu'],index_col='waktu')
df.head()
df.plot(figsize=(12,8));

fig, ax = plt.subplots(figsize=(12, 8))
sm.graphics.tsa.plot_acf(df, lags=20, ax=ax);

mk.original_test(df, alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='increasing', h=True, p=0.01341368409221566, z=2.4725929121191705, Tau=0.12591133004926108, s=1917.0, var_s=600462.3333333334, slope=1.2181818181818182e-07, intercept=6.13018181818182e-05)

# %%
# read all datasets
df = pd.read_csv("CO.csv",parse_dates=['waktu'],index_col='waktu')
df.head()
df.plot(figsize=(12,8));

fig, ax = plt.subplots(figsize=(12, 8))
sm.graphics.tsa.plot_acf(df, lags=20, ax=ax);

mk.original_test(df, alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='decreasing', h=True, p=0.001700836036813147, z=-3.1380366587795687, Tau=-0.1063922826173376, s=-8029.0, var_s=6544835.0, slope=-7.936507936507943e-06, intercept=0.037539682539682546)

# %%
# read all datasets
df = pd.read_csv("O3.csv",parse_dates=['waktu'],index_col='waktu')
df.head()
df.plot(figsize=(12,8));

fig, ax = plt.subplots(figsize=(12, 8))
sm.graphics.tsa.plot_acf(df, lags=20, ax=ax);

mk.original_test(df, alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='decreasing', h=True, p=9.233749298509508e-08, z=-5.341191806097288, Tau=-0.13754205333152703, s=-30458.0, var_s=32516058.666666668, slope=-2.8653295128939457e-06, intercept=0.11695272206303722)

# %%
# read all datasets
df = pd.read_csv("SO2.csv",parse_dates=['waktu'],index_col='waktu')
df.head()
df.plot(figsize=(12,8));

fig, ax = plt.subplots(figsize=(12, 8))
sm.graphics.tsa.plot_acf(df, lags=20, ax=ax);

mk.original_test(df, alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.3803054400862629, z=-0.8773336499727815, Tau=-0.0398810271878011, s=-952.0, var_s=1174982.6666666667, slope=-3.054054054054055e-07, intercept=2.14891891891892e-05)

# %%
# read all datasets
df = pd.read_csv("AOD.csv",parse_dates=['waktu'],index_col='waktu')
df.head()
df.plot(figsize=(12,8));

fig, ax = plt.subplots(figsize=(12, 8))
sm.graphics.tsa.plot_acf(df, lags=20, ax=ax);

mk.original_test(df, alpha=0.05)
# Out:
# Mann_Kendall_Test(trend='no trend', h=False, p=0.9537986561786527, z=0.05793719420218545, Tau=0.005456349206349206, s=11.0, var_s=29791.0, slope=0.030638744769647622, intercept=250.7128663397561)

# %%
df = pd.read_csv("depok.csv")
df.head()
df.describe()
# Out:
#                AOD          CO         NO2          O3         SO2
# count    64.000000  389.000000  175.000000  666.000000  219.000000
# mean    299.325397    0.036884    0.000074    0.115718    0.000026
# std     202.662155    0.007198    0.000036    0.002813    0.000428
# min      41.199770    0.022000    0.000003    0.106000   -0.000940
# 25%     164.029500    0.032000    0.000052    0.114000   -0.000213
# 50%     251.677987    0.036000    0.000072    0.116000   -0.000012
# 75%     374.024991    0.040000    0.000092    0.118000    0.000223
# max    1095.934370    0.075000    0.000215    0.123000    0.002497
